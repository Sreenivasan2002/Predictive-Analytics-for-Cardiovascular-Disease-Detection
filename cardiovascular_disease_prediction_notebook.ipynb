# %% [markdown]
# PROBLEM STATEMENT

# %% [markdown]
# Aim of the problem is to detect the presence or absence of cardiovascular disease in person based on the given features.
# Features available are:
#
#
# - Age | Objective Feature | age | int (days)
# - Height | Objective Feature | height | int (cm) |
# - Weight | Objective Feature | weight | float (kg) |
# - Gender | Objective Feature | gender | categorical code |
# - Systolic blood pressure | Examination Feature | ap_hi | int |
# - Diastolic blood pressure | Examination Feature | ap_lo | int |
# - Cholesterol | Examination Feature | cholesterol | 1: normal, 2: above normal, 3: well above normal |
# - Glucose | Examination Feature | gluc | 1: normal, 2: above normal, 3: well above normal |
# - Smoking | Subjective Feature | smoke | binary |
# - Alcohol intake | Subjective Feature | alco | binary |
# - Physical activity | Subjective Feature | active | binary |
# - Presence or absence of cardiovascular disease | Target Variable | cardio | binary |

# %% [markdown]
# # IMPORT LIBRARIES AND DATASETS

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file
cardio_df = pd.read_csv("cardio_train.csv", sep=";")

# %%
cardio_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
cardio_df.tail()
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  52.712329       2     168    76.0    120     80            1     1
# 69996  61.920548       1     158   126.0    140     90            2     2
# 69997  52.235616       2     183   105.0    180     90            3     1
# 69998  61.454795       1     163    72.0    135     80            1     2
# 69999  56.273973       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# # PERFORMING EXPLORATORY DATA ANALYSIS

# %%
# Drop id

cardio_df = cardio_df.drop(columns = 'id')

# %%
# since the age is given in days, we convert it into years

cardio_df['age'] = cardio_df['age']/365

# %%
cardio_df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  50.391781       2     168    62.0    110     80            1     1      0
# 1  55.419178       1     156    85.0    140     90            3     1      0
# 2  51.663014       1     165    64.0    130     70            3     1      0
# 3  48.282192       2     169    82.0    150    100            1     1      0
# 4  47.873973       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# checking the null values
cardio_df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Checking the dataframe information

cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 6.4 MB

# %%
# Statistical summary of the dataframe
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.339358      1.349571    164.359229     74.205690    128.817286
# std        6.759594      0.476838      8.210126     14.395757    154.011419
# min       29.583562      1.000000     55.000000     10.000000   -150.000000
# 25%       48.394521      1.000000    159.000000     65.000000    120.000000
# 50%       53.980822      1.000000    165.000000     72.000000    120.000000
# 75%       58.430137      2.000000    170.000000     82.000000    140.000000
# max       64.967123      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
cardio_df[cardio_df['age'] >64]
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 23     64.043836       2     156    45.0    110     60            1     1
# 38     64.076712       2     162    72.0    130     80            1     1
# 70     64.627397       1     155    57.0    120     80            1     1
# 72     64.200000       1     156    58.0    110     70            1     1
# 142    64.043836       2     169    73.0    140     90            1     1
# ...          ...     ...     ...     ...    ...    ...          ...   ...
# 69862  64.378082       2     166    99.0    120     80            1     1
# 69865  64.783562       1     149    49.0    115     75            1     1
# 69896  64.252055       1     150    69.0    120     80            1     1
# 69936  64.145205       2     171    70.0    140     90            1     1
# 69944  64.284932       2     170    97.0    130     90            2     1
#
#        smoke  alco  active  cardio
# 23         0     0       1       0
# 38         1     0       1       1
# 70         0     0       1       1
# 72         0     0       1       0
# 142        0     0       1       1
# ...      ...   ...     ...     ...
# 69862      0     0       1       1
# 69865      0     0       1       0
# 69896      0     0       1       1
# 69936      0     0       1       0
# 69944      0     0       1       1
#
# [2177 rows x 12 columns]

# %% [markdown]
# # VISUALIZING THE DATASET

# %% [markdown]
# - ploting the histogram for all features (use 20 bins)
# - ploting the correlation matrix and indicating if there exists any correlations between features

# %%
cardio_df.hist(bins = 20, figsize = (20,20), color = 'r')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'ap_hi'}>,
#         <Axes: title={'center': 'ap_lo'}>],
#        [<Axes: title={'center': 'cholesterol'}>,
#         <Axes: title={'center': 'gluc'}>,
#         <Axes: title={'center': 'smoke'}>],
#        [<Axes: title={'center': 'alco'}>,
#         <Axes: title={'center': 'active'}>,
#         <Axes: title={'center': 'cardio'}>]], dtype=object)

# %%
sns.pairplot(cardio_df)

# %%
plt.figure(figsize = (16,16))
corr_matrix = cardio_df.corr()
sns.heatmap(corr_matrix, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # CREATEING TRAINING AND TESTING DATASET

# %%
# split the dataframe into target and features

df_target = cardio_df['cardio']
df_final = cardio_df.drop(columns =['cardio'])

# %%
cardio_df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df_final.shape
# Out:
# (70000, 11)

# %%
df_target.shape
# Out:
# (70000,)

# %%
#spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_final, df_target, test_size = 0.2)

# %%
X_train.shape
# Out:
# (56000, 11)

# %%
y_train.shape
# Out:
# (56000,)

# %%
X_test.shape
# Out:
# (14000, 11)

# %%
X_test.shape
# Out:
# (14000, 11)

# %% [markdown]
# # TRAINING AND TEST XGBOOST MODEL

# %%
# install xgboost

# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
# XGboost is a type of ensemble algorithms and works by selecting thresholds or cut points on features to split a node.

from xgboost import XGBClassifier

model = XGBClassifier(learning_rate=0.01, n_estimators=500, max_depth = 20)
#model = XGBClassifier()

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=20, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# making predictions on test data

predict = model.predict(X_test)

# %%
predict
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
# Assess trained model performance on training dataset
predict_train = model.predict(X_train)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, predict_train)
plt.figure()
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
# print metrics for training dataset

from sklearn.metrics import precision_score, recall_score, accuracy_score

print("Precision = {}".format(precision_score(y_train, predict_train)))
print("Recall = {}".format(recall_score(y_train, predict_train)))
print("Accuracy = {}".format(accuracy_score(y_train, predict_train)))
# Out:
# Precision = 0.9429818019093079
# Recall = 0.8998291936516973
# Accuracy = 0.9224285714285714

# %%
# print metrics for testing dataset

print("Precision = {}".format(precision_score(y_test, predict)))
print("Recall = {}".format(recall_score(y_test, predict)))
print("Accuracy = {}".format(accuracy_score(y_test, predict)))
# Out:
# Precision = 0.7519949929588484
# Recall = 0.6988512432746837
# Accuracy = 0.7388571428571429

# %%
from sklearn.metrics import f1_score

# Calculate F1 score for training dataset
f1_train = f1_score(y_train, predict_train)
print("F1 Score (Training) = {}".format(f1_train))

# Calculate F1 score for testing dataset
f1_test = f1_score(y_test, predict)
print("F1 Score (Testing) = {}".format(f1_test))
# Out:
# F1 Score (Training) = 0.9209002512837321
# F1 Score (Testing) = 0.724449804039795

# %%
# plot the confusion matrix

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict)
plt.figure()
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# E
#  - Retraining the XGBoost algorithm with large number of estimators (n_estimators = 500) and more depth (max_depth = 20)

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Calculate the false positive rate (fpr), true positive rate (tpr), and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
xgb_model = XGBClassifier(learning_rate=0.01, n_estimators=500, max_depth = 20)
xgb_model.fit(X_train, y_train)

# %% [markdown]
# E
# - Tuning the XGBoost classifier using gridsearch, start with the param_grid listed below

# %%
param_grid = {
        'gamma': [0.5, 1, 5],   # regularization parameter
        'subsample': [0.6, 0.8, 1.0], # % of rows taken to build each tree
        'colsample_bytree': [0.6, 0.8, 1.0], # number of columns used by each tree
        'max_depth': [3, 4, 5] # depth of each tree
        }

# %%
from sklearn.model_selection import GridSearchCV
xgb_model = XGBClassifier(learning_rate=0.01, n_estimators=100, objective='binary:logistic')
grid = GridSearchCV(xgb_model, param_grid, refit = True, verbose = 4)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.734 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.732 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.730 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.734 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.733 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.734 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.733 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.730 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.734 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.739 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.734 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.735 total time=   2.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.737 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.731 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.728 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.734 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.732 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.730 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.734 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.733 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.729 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.734 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.733 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.724 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.734 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.734 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.736 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.737 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.727 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.731 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=1.0;, score=0.738 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=1.0;, score=0.736 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=1.0;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=1.0;, score=0.728 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=1.0;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.6;, score=0.734 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.6;, score=0.732 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.6;, score=0.730 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.6;, score=0.724 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.6;, score=0.727 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.8;, score=0.734 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.8;, score=0.733 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.8;, score=0.729 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.8;, score=0.724 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=1.0;, score=0.734 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=1.0;, score=0.733 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=1.0;, score=0.730 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=1.0;, score=0.724 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=3, subsample=1.0;, score=0.726 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.6;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.6;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.8;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.8;, score=0.734 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.8;, score=0.736 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=0.8;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=1.0;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.6;, score=0.739 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.6;, score=0.727 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.6;, score=0.732 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.8;, score=0.738 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.8;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=0.8;, score=0.731 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=1.0;, score=0.738 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=1.0;, score=0.736 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=1.0;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=5, max_depth=5, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.721 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.732 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.720 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=1.0;, score=0.728 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=1.0;, score=0.721 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=3, subsample=1.0;, score=0.727 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.739 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.734 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.735 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=0.8;, score=0.731 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=1.0;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=1.0;, score=0.726 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.737 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.6;, score=0.733 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.736 total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.736 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=0.8;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=1.0;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=1.0;, score=0.737 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=1.0;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=1.0;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.5, max_depth=5, subsample=1.0;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.721 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.732 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.720 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=1.0;, score=0.728 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=1.0;, score=0.721 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=3, subsample=1.0;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.734 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.725 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.6;, score=0.731 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.726 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=1.0;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=1.0;, score=0.726 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.737 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.6;, score=0.733 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=0.8;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=1.0;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=1.0;, score=0.736 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=1.0;, score=0.735 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=1.0;, score=0.727 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, max_depth=5, subsample=1.0;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.6;, score=0.721 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.6;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.8;, score=0.732 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.8;, score=0.720 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=1.0;, score=0.728 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=1.0;, score=0.721 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=3, subsample=1.0;, score=0.727 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.6;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.6;, score=0.734 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.6;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.8;, score=0.739 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.8;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.8;, score=0.726 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=0.8;, score=0.731 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=1.0;, score=0.740 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=1.0;, score=0.734 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=1.0;, score=0.725 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.6;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.6;, score=0.737 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.6;, score=0.725 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.6;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.8;, score=0.741 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.8;, score=0.736 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.8;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=0.8;, score=0.732 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=1.0;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=1.0;, score=0.737 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=1.0;, score=0.735 total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=1.0;, score=0.728 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=5, max_depth=5, subsample=1.0;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.6;, score=0.724 total time=   0.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.6;, score=0.725 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.6;, score=0.719 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.8;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.8;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.8;, score=0.719 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=0.8;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=1.0;, score=0.727 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=1.0;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=1.0;, score=0.725 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=1.0;, score=0.719 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=3, subsample=1.0;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.8;, score=0.737 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.8;, score=0.732 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.8;, score=0.723 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=1.0;, score=0.737 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=1.0;, score=0.724 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=4, subsample=1.0;, score=0.730 total time=   1.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.6;, score=0.740 total time=   1.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.6;, score=0.725 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.6;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.8;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.8;, score=0.724 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=0.8;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=1.0;, score=0.739 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=1.0;, score=0.734 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=1.0;, score=0.734 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=1.0;, score=0.725 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, max_depth=5, subsample=1.0;, score=0.729 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.6;, score=0.719 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.719 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.725 total time=   1.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.727 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.724 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.719 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.725 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.736 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.733 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.724 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.737 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.732 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.723 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.729 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.737 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.725 total time=   0.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.730 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.740 total time=   0.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.724 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.739 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.734 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.734 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.725 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.728 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.719 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.727 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.724 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.725 total time=   2.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.719 total time=   1.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.725 total time=   2.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.727 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.724 total time=   0.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.725 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.719 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.725 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.733 total time=   1.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.734 total time=   1.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.729 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.737 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.731 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.732 total time=   0.9s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.723 total time=   2.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.729 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.737 total time=   1.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.731 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.724 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.741 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.736 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.725 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.730 total time=   0.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.740 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.735 total time=   1.7s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.735 total time=   2.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.724 total time=   2.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.730 total time=   1.0s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.739 total time=   0.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.735 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.733 total time=   0.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.726 total time=   0.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.729 total time=   0.5s
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=0.01, max_b...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=100,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 5], 'max_depth': [3, 4, 5],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=4)

# %%
y_predict_optim = grid.predict(X_test)

# %%
y_predict_optim
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
# print metrics for testing dataset

print("Precision = {}".format(precision_score(y_test, y_predict_optim)))
print("Recall = {}".format(recall_score(y_test, y_predict_optim)))
print("Accuracy = {}".format(accuracy_score(y_test, y_predict_optim)))
# Out:
# Precision = 0.75493316359007
# Recall = 0.6898356841646066
# Accuracy = 0.7376428571428572
